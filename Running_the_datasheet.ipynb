# %%
import pandas as pd

# %% [markdown]
# # Loading the Datasheet

# %%
pd.read_csv('datasheet_ordered.csv')
# Out:
#         GC Content  Fickett Score  ORF Length  Relative Codon Bias  \
# 0         0.359435         0.3871       981.0             0.284229
# 1         0.460064         0.9340       939.0             0.460470
# 2         0.460064         0.9340       939.0             0.460470
# 3         0.699278         1.0718      2535.0             0.270346
# 4         0.699250         1.0718      2538.0             0.271500
# ...            ...            ...         ...                  ...
# 169294    0.488243         0.6109       216.0             0.573883
# 169295    0.589937         0.5607       693.0             0.561706
# 169296    0.421512         0.5711        81.0             0.708203
# 169297    0.589909         0.7649       393.0             0.556396
# 169298    0.525617         0.4788       369.0             0.426959
#
#         Isoelectronic Point  Aromaticity  Transcript Length  ORF Coverage  \
# 0                  9.588915     0.112385             2618.0      0.374714
# ...

# %%
datasheet = pd.read_csv('datasheet_ordered.csv')

# %%
datasheet.head()
# Out:
#    GC Content  Fickett Score  ORF Length  Relative Codon Bias  \
# 0    0.359435         0.3871       981.0             0.284229
# 1    0.460064         0.9340       939.0             0.460470
# 2    0.460064         0.9340       939.0             0.460470
# 3    0.699278         1.0718      2535.0             0.270346
# 4    0.699250         1.0718      2538.0             0.271500
#
#    Isoelectronic Point  Aromaticity  Transcript Length  ORF Coverage  \
# 0             9.588915     0.112385             2618.0      0.374714
# 1             9.042610     0.137821              939.0      1.000000
# 2             9.042610     0.137821              939.0      1.000000
# 3            11.870000     0.051948             3465.0      0.731602
# 4            11.870000     0.051903             3468.0      0.731834
#
#    CpG Islands  Coding(1) / Non-Coding(0)
# 0         18.0                        1.0
# 1          8.0                        1.0
# 2          8.0                        1.0
# ...

# %%
datasheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169299 entries, 0 to 169298
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   GC Content                 169299 non-null  float64
#  1   Fickett Score              169299 non-null  float64
#  2   ORF Length                 169299 non-null  float64
#  3   Relative Codon Bias        169299 non-null  float64
#  4   Isoelectronic Point        169299 non-null  float64
#  5   Aromaticity                169299 non-null  float64
#  6   Transcript Length          169299 non-null  float64
#  7   ORF Coverage               169299 non-null  float64
#  8   CpG Islands                169299 non-null  float64
#  9   Coding(1) / Non-Coding(0)  169299 non-null  float64
# dtypes: float64(10)
# memory usage: 12.9 MB

# %% [markdown]
# ### Describe the summary of each numerical attribute

# %%
datasheet.describe()
# Out:
#           GC Content  Fickett Score     ORF Length  Relative Codon Bias  \
# count  169299.000000  169299.000000  169299.000000        169299.000000
# mean        0.491757       0.682215     850.350717             0.429675
# std         0.081175       0.245921    1350.076167             0.125612
# min         0.210762       0.308600       0.000000             0.000000
# 25%         0.428519       0.478200     168.000000             0.345495
# 50%         0.482423       0.626000     345.000000             0.413945
# 75%         0.552177       0.851400    1122.000000             0.498194
# max         0.833333       1.389500  107976.000000             3.518765
#
#        Isoelectronic Point    Aromaticity  Transcript Length   ORF Coverage  \
# count        169299.000000  169299.000000      169299.000000  169299.000000
# mean              9.213471       0.082545        2021.595798       0.380847
# std               1.547638       0.027155        2312.112141       0.251062
# ...

# %% [markdown]
# # Plotting Graphs

# %% [markdown]
# ### Histogram for each numerical attributes

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
datasheet.hist(bins = 50, figsize = (20, 15))
plt.show()

# %% [markdown]
# # Creating Test Set

# %% [markdown]
# ### The Test Set made will be fixed

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(datasheet, test_size = 0.2, random_state = 42)

# %%
test_set
# Out:
#         GC Content  Fickett Score  ORF Length  Relative Codon Bias  \
# 56186     0.514863         0.6247       678.0             0.492885
# 24088     0.400856         0.3834       246.0             0.417610
# 63171     0.607200         1.0924      2277.0             0.455051
# 15113     0.533879         1.2767       102.0             0.551477
# 154805    0.405885         0.3666       207.0             0.304613
# ...            ...            ...         ...                  ...
# 44920     0.592040         1.1083       273.0             0.750115
# 140948    0.461970         0.4387       177.0             0.345064
# 162466    0.484305         0.6703        75.0             0.461658
# 165786    0.471186         0.4413       225.0             0.503839
# 20986     0.427574         0.8271       129.0             0.705843
#
#         Isoelectronic Point  Aromaticity  Transcript Length  ORF Coverage  \
# 56186              9.184505     0.071429              841.0      0.806183
# ...

# %%
train_set
# Out:
#         GC Content  Fickett Score  ORF Length  Relative Codon Bias  \
# 13037     0.531569         1.1667      3423.0             0.361331
# 4929      0.430851         0.6584       552.0             0.385614
# 38519     0.441597         0.6885      1125.0             0.332332
# 39450     0.409201         1.1604      2244.0             0.328830
# 5507      0.515982         1.0008       219.0             0.731857
# ...            ...            ...         ...                  ...
# 119879    0.448630         0.4261       138.0             0.496525
# 103694    0.402305         0.6674      3378.0             0.282702
# 131932    0.394353         0.3899       171.0             0.364444
# 146867    0.422983         0.4762       123.0             0.339916
# 121958    0.472897         0.5461       114.0             0.409274
#
#         Isoelectronic Point  Aromaticity  Transcript Length  ORF Coverage  \
# 13037              5.388814     0.091811             3627.0      0.943755
# ...

# %% [markdown]
# ### Scatterplot

# %%
train_set.plot(kind = "scatter", x = "Fickett Score", y = "ORF Length", alpha = 0.1)
# Out:
# <Axes: xlabel='Fickett Score', ylabel='ORF Length'>

# %%
datasheet.corr()
# Out:
#                            GC Content  Fickett Score  ORF Length  \
# GC Content                   1.000000       0.532638    0.024237
# Fickett Score                0.532638       1.000000    0.220693
# ORF Length                   0.024237       0.220693    1.000000
# Relative Codon Bias          0.233421       0.244601   -0.273326
# Isoelectronic Point          0.041557      -0.099522    0.004281
# Aromaticity                 -0.642946      -0.409438   -0.005314
# Transcript Length           -0.123170      -0.092015    0.691164
# ORF Coverage                 0.214122       0.503070    0.536352
# CpG Islands                  0.338407       0.211803    0.682418
# Coding(1) / Non-Coding(0)    0.231250       0.474202    0.336326
#
#                            Relative Codon Bias  Isoelectronic Point  \
# GC Content                            0.233421             0.041557
# Fickett Score                         0.244601            -0.099522
# ...
